# %%
! dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 7AAF-ADF0
#
#  Directory of C:\Users\gaoyu\Documents\GitHub\dr_wang_airflow_tutorial
#
# 16/07/2022  10:09 PM    <DIR>          .
# 16/07/2022  10:05 PM    <DIR>          ..
# 16/07/2022  10:08 PM    <DIR>          .ipynb_checkpoints
# 16/07/2022  10:05 PM               102 README.md
# 16/07/2022  10:09 PM               834 run_airflow_locally.ipynb
#                2 File(s)            936 bytes
#                3 Dir(s)  359,174,082,560 bytes free

# %%
! set AIRFLOW_HOME=~/airflow

# %%
! set AIRFLOW_VERSION=2.3.3

# %%
! set PYTHON_VERSION=3.9.6

# %%
! set CONSTRAINT_URL="https://raw.githubusercontent.com/apache/airflow/constraints-${AIRFLOW_VERSION}/constraints-${PYTHON_VERSION}.txt"

# %%
! echo ${CONSTRAINT_URL}
# Out:
# ${CONSTRAINT_URL}

# %%
! pip install "apache-airflow==${AIRFLOW_VERSION}" --constraint "${CONSTRAINT_URL}"
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: '${CONSTRAINT_URL}'
# WARNING: You are using pip version 21.1.3; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\users\gaoyu\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install apache-airflow
# Out:
# Collecting apache-airflow
#   Downloading apache_airflow-2.3.3-py3-none-any.whl (5.5 MB)
# Collecting connexion[flask,swagger-ui]>=2.10.0
#   Downloading connexion-2.14.0-py2.py3-none-any.whl (95 kB)
# Collecting blinker
#   Downloading blinker-1.4.tar.gz (111 kB)
# Collecting flask-caching>=1.5.0
#   Downloading Flask_Caching-2.0.0-py3-none-any.whl (28 kB)
# Collecting mdit-py-plugins>=0.3.0
#   Downloading mdit_py_plugins-0.3.0-py3-none-any.whl (43 kB)
# Requirement already satisfied: flask>=2.0 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from apache-airflow) (2.1.1)
# Collecting apache-airflow-providers-ftp
#   Downloading apache_airflow_providers_ftp-3.0.0-py3-none-any.whl (16 kB)
# Collecting python-daemon>=2.2.4
#   Downloading python_daemon-2.3.0-py2.py3-none-any.whl (35 kB)
# Collecting alembic<2.0,>=1.5.1
#   Downloading alembic-1.8.1-py3-none-any.whl (209 kB)
# Requirement already satisfied: pyjwt>=2.0.0 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from apache-airflow) (2.4.0)
# Collecting cattrs!=1.7.*,~=1.1
#   Downloading cattrs-1.10.0-py3-none-any.whl (29 kB)
# Collecting deprecated>=1.2.13
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Collecting attrs<21.0,>=20.0
#   Downloading attrs-20.3.0-py2.py3-none-any.whl (49 kB)
# Collecting apache-airflow-providers-http
#   Downloading apache_airflow_providers_http-3.0.0-py3-none-any.whl (19 kB)
# Collecting python-nvd3>=0.15.0
#   Downloading python-nvd3-0.15.0.tar.gz (31 kB)
# Collecting markdown-it-py>=2.1.0
#   Downloading markdown_it_py-2.1.0-py3-none-any.whl (84 kB)
# Collecting python-slugify>=5.0
#   Downloading python_slugify-6.1.2-py2.py3-none-any.whl (9.4 kB)
# Collecting dill>=0.2.2
#   Downloading dill-0.3.5.1-py2.py3-none-any.whl (95 kB)
# Collecting cron-descriptor>=1.2.24
#   Downloading cron_descriptor-1.2.31.tar.gz (28 kB)
# Collecting cryptography>=0.9.3
#   Downloading cryptography-37.0.4-cp36-abi3-win_amd64.whl (2.4 MB)
# Collecting rich>=12.4.4
#   Downloading rich-12.5.1-py3-none-any.whl (235 kB)
# Requirement already satisfied: markdown>=3.0 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from apache-airflow) (3.3.6)
# Collecting flask-wtf>=0.15
#   Downloading Flask_WTF-1.0.1-py3-none-any.whl (12 kB)
# Collecting marshmallow-oneofschema>=2.0.1
#   Downloading marshmallow_oneofschema-3.0.1-py2.py3-none-any.whl (5.8 kB)
# Collecting lazy-object-proxy
#   Downloading lazy_object_proxy-1.7.1-cp39-cp39-win_amd64.whl (22 kB)
# Collecting linkify-it-py>=2.0.0
#   Downloading linkify_it_py-2.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from apache-airflow) (4.2.0)
# Collecting unicodecsv>=0.14.1
#   Downloading unicodecsv-0.14.1.tar.gz (10 kB)
# Collecting flask-login>=0.5
#   Downloading Flask_Login-0.6.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: psutil>=4.2.0 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from apache-airflow) (5.9.0)
# Collecting gunicorn>=20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Requirement already satisfied: tabulate>=0.7.5 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from apache-airflow) (0.8.9)
# Collecting colorlog<5.0,>=4.0.2
#   Downloading colorlog-4.8.0-py2.py3-none-any.whl (10 kB)
# Collecting setproctitle>=1.1.8
#   Downloading setproctitle-1.2.3-cp39-cp39-win_amd64.whl (10 kB)
# Collecting flask-appbuilder==4.1.2
#   Downloading Flask_AppBuilder-4.1.2-py3-none-any.whl (1.8 MB)
# Requirement already satisfied: python-dateutil>=2.3 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from apache-airflow) (2.8.2)
# Collecting pathspec~=0.9.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting pluggy>=1.0
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Collecting pendulum>=2.0
#   Downloading pendulum-2.1.2.tar.gz (81 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: pygments>=2.0.1 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from apache-airflow) (2.11.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from apache-airflow) (2.1.2)
# Collecting lockfile>=0.12.2
#   Downloading lockfile-0.12.2-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: sqlalchemy>=1.4 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from apache-airflow) (1.4.35)
# Collecting graphviz>=0.12
#   Downloading graphviz-0.20-py3-none-any.whl (46 kB)
# Requirement already satisfied: packaging>=14.0 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from apache-airflow) (21.3)
# Collecting sqlalchemy-jsonfield>=1.0
#   Downloading SQLAlchemy_JSONField-1.0.0-py3-none-any.whl (10 kB)
# Collecting apache-airflow-providers-sqlite
#   Downloading apache_airflow_providers_sqlite-3.0.0-py3-none-any.whl (14 kB)
# Collecting apache-airflow-providers-imap
#   Downloading apache_airflow_providers_imap-3.0.0-py3-none-any.whl (16 kB)
# Collecting argcomplete>=1.10
#   Downloading argcomplete-2.0.0-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: markupsafe>=1.1.1 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from apache-airflow) (2.1.1)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.0.1-py3-none-any.whl (24 kB)
# Collecting httpx
#   Downloading httpx-0.23.0-py3-none-any.whl (84 kB)
# Requirement already satisfied: jsonschema>=3.2.0 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from apache-airflow) (4.4.0)
# Requirement already satisfied: jinja2>=2.10.1 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from apache-airflow) (3.1.1)
# Collecting flask-session>=0.4.0
#   Downloading Flask_Session-0.4.0-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: werkzeug>=2.0 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from apache-airflow) (2.1.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from apache-airflow) (1.1.0)
# Collecting croniter>=0.3.17
#   Downloading croniter-1.3.5-py2.py3-none-any.whl (17 kB)
# Collecting Flask-JWT-Extended<5.0.0,>=4.0.0
#   Downloading Flask_JWT_Extended-4.4.2-py2.py3-none-any.whl (21 kB)
# Collecting WTForms<3.0.0
#   Downloading WTForms-2.3.3-py2.py3-none-any.whl (169 kB)
# Collecting apispec[yaml]<4,>=3.3
#   Downloading apispec-3.3.2-py2.py3-none-any.whl (27 kB)
# Collecting Flask-SQLAlchemy<3,>=2.4
#   Downloading Flask_SQLAlchemy-2.5.1-py2.py3-none-any.whl (17 kB)
# Collecting flask-wtf>=0.15
#   Downloading Flask_WTF-0.15.1-py2.py3-none-any.whl (13 kB)
# Collecting marshmallow<4,>=3
#   Downloading marshmallow-3.17.0-py3-none-any.whl (48 kB)
# Collecting sqlalchemy-utils<1,>=0.32.21
#   Downloading SQLAlchemy_Utils-0.38.3-py3-none-any.whl (100 kB)
# Collecting prison<1.0.0,>=0.2.1
#   Downloading prison-0.2.1-py2.py3-none-any.whl (5.8 kB)
# Collecting marshmallow-enum<2,>=1.5.1
#   Downloading marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Collecting Flask-Babel<3,>=1
#   Downloading Flask_Babel-2.0.0-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: click<9,>=8 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from flask-appbuilder==4.1.2->apache-airflow) (8.1.2)
# Requirement already satisfied: colorama<1,>=0.3.9 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from flask-appbuilder==4.1.2->apache-airflow) (0.4.4)
# Collecting email-validator<2,>=1.0.5
#   Downloading email_validator-1.2.1-py2.py3-none-any.whl (22 kB)
# Collecting marshmallow-sqlalchemy<0.27.0,>=0.22.0
#   Downloading marshmallow_sqlalchemy-0.26.1-py2.py3-none-any.whl (15 kB)
# Collecting Mako
#   Downloading Mako-1.2.1-py3-none-any.whl (78 kB)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from apispec[yaml]<4,>=3.3->flask-appbuilder==4.1.2->apache-airflow) (6.0)
# Collecting inflection<0.6,>=0.3.1
#   Downloading inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Collecting clickclick<21,>=1.2
#   Downloading clickclick-20.10.2-py2.py3-none-any.whl (7.4 kB)
# Requirement already satisfied: requests<3,>=2.9.1 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from connexion[flask,swagger-ui]>=2.10.0->apache-airflow) (2.27.1)
# Collecting swagger-ui-bundle<0.1,>=0.0.2
#   Downloading swagger_ui_bundle-0.0.9-py3-none-any.whl (6.2 MB)
# Requirement already satisfied: cffi>=1.12 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from cryptography>=0.9.3->apache-airflow) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from cffi>=1.12->cryptography>=0.9.3->apache-airflow) (2.21)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from deprecated>=1.2.13->apache-airflow) (1.14.0)
# Requirement already satisfied: idna>=2.0.0 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from email-validator<2,>=1.0.5->flask-appbuilder==4.1.2->apache-airflow) (3.3)
# Collecting dnspython>=1.15.0
#   Downloading dnspython-2.2.1-py3-none-any.whl (269 kB)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from flask>=2.0->apache-airflow) (4.11.3)
# Requirement already satisfied: Babel>=2.3 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from Flask-Babel<3,>=1->flask-appbuilder==4.1.2->apache-airflow) (2.10.1)
# Requirement already satisfied: pytz in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from Flask-Babel<3,>=1->flask-appbuilder==4.1.2->apache-airflow) (2022.1)
# Collecting cachelib>=0.9.0
#   Downloading cachelib-0.9.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: setuptools>=3.0 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from gunicorn>=20.1.0->apache-airflow) (56.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from importlib-metadata>=3.6.0->flask>=2.0->apache-airflow) (3.8.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=3.2.0->apache-airflow) (0.18.1)
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.1-py3-none-any.whl (6.2 kB)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from packaging>=14.0->apache-airflow) (3.0.8)
# Collecting pytzdata>=2020.1
#   Downloading pytzdata-2020.1-py2.py3-none-any.whl (489 kB)
# Requirement already satisfied: six in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from prison<1.0.0,>=0.2.1->flask-appbuilder==4.1.2->apache-airflow) (1.16.0)
# Requirement already satisfied: docutils in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from python-daemon>=2.2.4->apache-airflow) (0.17.1)
# Collecting text-unidecode>=1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.9.1->connexion[flask,swagger-ui]>=2.10.0->apache-airflow) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.9.1->connexion[flask,swagger-ui]>=2.10.0->apache-airflow) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.9.1->connexion[flask,swagger-ui]>=2.10.0->apache-airflow) (1.26.9)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages (from sqlalchemy>=1.4->apache-airflow) (1.1.2)
# Collecting httpcore<0.16.0,>=0.15.0
#   Downloading httpcore-0.15.0-py3-none-any.whl (68 kB)
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Collecting h11<0.13,>=0.11
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
# Collecting anyio==3.*
#   Downloading anyio-3.6.1-py3-none-any.whl (80 kB)
# Building wheels for collected packages: cron-descriptor, pendulum, python-nvd3, unicodecsv, blinker
#   Building wheel for cron-descriptor (setup.py): started
#   Building wheel for cron-descriptor (setup.py): finished with status 'done'
#   Created wheel for cron-descriptor: filename=cron_descriptor-1.2.31-py3-none-any.whl size=46615 sha256=599b5ef4a1492bb7ab22691b75dcc55353f88fe01d7b234c6a42848caf3e1ffc
#   Stored in directory: c:\users\gaoyu\appdata\local\pip\cache\wheels\a9\1a\d5\55690171f91f1f955a424aebd5d4859ed194730a1eca38e756
#   Building wheel for pendulum (PEP 517): started
#   Building wheel for pendulum (PEP 517): finished with status 'done'
#   Created wheel for pendulum: filename=pendulum-2.1.2-cp39-cp39-win_amd64.whl size=109761 sha256=f5007b687ce1ca369b09a6752a9e14058864ed3d2086684716f6d42e6cfac921
#   Stored in directory: c:\users\gaoyu\appdata\local\pip\cache\wheels\c9\c7\29\3cf0033406b18958d1a7b107c38be2405ef9c081b64a264fd5
#   Building wheel for python-nvd3 (setup.py): started
#   Building wheel for python-nvd3 (setup.py): finished with status 'done'
#   Created wheel for python-nvd3: filename=python_nvd3-0.15.0-py3-none-any.whl size=38155 sha256=18c6d46846d3df4058e627a3c26f964e01e63823548958774397d9f5e90f25c9
#   Stored in directory: c:\users\gaoyu\appdata\local\pip\cache\wheels\60\e8\21\19a3dcfe90e8895952857d42152663fafc5a90d87d3dfe5f58
#   Building wheel for unicodecsv (setup.py): started
#   Building wheel for unicodecsv (setup.py): finished with status 'done'
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-py3-none-any.whl size=10768 sha256=e9ad03ac8cad02ace19874cf90d9c549718004aff51ffe68c07e747fd71f1cf5
#   Stored in directory: c:\users\gaoyu\appdata\local\pip\cache\wheels\d8\c8\27\b237d3378d5c9ed25c2c63d9af1b3d5ccb99934f3dd030de87
#   Building wheel for blinker (setup.py): started
#   Building wheel for blinker (setup.py): finished with status 'done'
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13451 sha256=a8bc36c4cdd4c8bfbf9e1c090353ca5e54b5102b486bbe82139732b313f0339c
#   Stored in directory: c:\users\gaoyu\appdata\local\pip\cache\wheels\50\93\f8\4f0a42a03a06626d675f13907b6982ad5ecff383530af5a900
# Successfully built cron-descriptor pendulum python-nvd3 unicodecsv blinker
# Installing collected packages: sniffio, attrs, WTForms, text-unidecode, rfc3986, mdurl, marshmallow, inflection, h11, dnspython, clickclick, apispec, anyio, uc-micro-py, swagger-ui-bundle, sqlalchemy-utils, pytzdata, python-slugify, prison, marshmallow-sqlalchemy, marshmallow-enum, markdown-it-py, Mako, lockfile, httpcore, flask-wtf, Flask-SQLAlchemy, flask-login, Flask-JWT-Extended, Flask-Babel, email-validator, connexion, commonmark, cachelib, unicodecsv, tenacity, sqlalchemy-jsonfield, setproctitle, rich, python-nvd3, python-daemon, pluggy, pendulum, pathspec, mdit-py-plugins, marshmallow-oneofschema, linkify-it-py, lazy-object-proxy, httpx, gunicorn, graphviz, flask-session, flask-caching, flask-appbuilder, dill, deprecated, cryptography, croniter, cron-descriptor, colorlog, cattrs, blinker, argcomplete, apache-airflow-providers-sqlite, apache-airflow-providers-imap, apache-airflow-providers-http, apache-airflow-providers-ftp, alembic, apache-airflow
#   Attempting uninstall: attrs
#     Found existing installation: attrs 21.4.0
#     Uninstalling attrs-21.4.0:
#       Successfully uninstalled attrs-21.4.0
# Successfully installed Flask-Babel-2.0.0 Flask-JWT-Extended-4.4.2 Flask-SQLAlchemy-2.5.1 Mako-1.2.1 WTForms-2.3.3 alembic-1.8.1 anyio-3.6.1 apache-airflow-2.3.3 apache-airflow-providers-ftp-3.0.0 apache-airflow-providers-http-3.0.0 apache-airflow-providers-imap-3.0.0 apache-airflow-providers-sqlite-3.0.0 apispec-3.3.2 argcomplete-2.0.0 attrs-20.3.0 blinker-1.4 cachelib-0.9.0 cattrs-1.10.0 clickclick-20.10.2 colorlog-4.8.0 commonmark-0.9.1 connexion-2.14.0 cron-descriptor-1.2.31 croniter-1.3.5 cryptography-37.0.4 deprecated-1.2.13 dill-0.3.5.1 dnspython-2.2.1 email-validator-1.2.1 flask-appbuilder-4.1.2 flask-caching-2.0.0 flask-login-0.6.1 flask-session-0.4.0 flask-wtf-0.15.1 graphviz-0.20 gunicorn-20.1.0 h11-0.12.0 httpcore-0.15.0 httpx-0.23.0 inflection-0.5.1 lazy-object-proxy-1.7.1 linkify-it-py-2.0.0 lockfile-0.12.2 markdown-it-py-2.1.0 marshmallow-3.17.0 marshmallow-enum-1.5.1 marshmallow-oneofschema-3.0.1 marshmallow-sqlalchemy-0.26.1 mdit-py-plugins-0.3.0 mdurl-0.1.1 pathspec-0.9.0 pendulum-2.1.2 pluggy-1.0.0 prison-0.2.1 python-daemon-2.3.0 python-nvd3-0.15.0 python-slugify-6.1.2 pytzdata-2020.1 rfc3986-1.5.0 rich-12.5.1 setproctitle-1.2.3 sniffio-1.2.0 sqlalchemy-jsonfield-1.0.0 sqlalchemy-utils-0.38.3 swagger-ui-bundle-0.0.9 tenacity-8.0.1 text-unidecode-1.3 uc-micro-py-1.0.1 unicodecsv-0.14.1
# WARNING: You are using pip version 21.1.3; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\users\gaoyu\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# !airflow standalone
# Out:
# standalone | Starting Airflow Standalone
# standalone | Checking database is initialized
# WARNING:root:OSError while attempting to symlink the latest log directory
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Running upgrade  -> e3a246e0dc1, current schema
# INFO  [alembic.runtime.migration] Running upgrade e3a246e0dc1 -> 1507a7289a2f, Add ``is_encrypted`` column in ``connection`` table
# INFO  [alembic.runtime.migration] Running upgrade 1507a7289a2f -> 13eb55f81627, Maintain history for compatibility with earlier migrations
# INFO  [alembic.runtime.migration] Running upgrade 13eb55f81627 -> 338e90f54d61, Add ``operator`` and ``queued_dttm`` to ``task_instance`` table
# INFO  [alembic.runtime.migration] Running upgrade 338e90f54d61 -> 52d714495f0, Add indices in ``job`` table
# INFO  [alembic.runtime.migration] Running upgrade 52d714495f0 -> 502898887f84, Adding ``extra`` column to ``Log`` table
# INFO  [alembic.runtime.migration] Running upgrade 502898887f84 -> 1b38cef5b76e, Add ``dag_run`` table
# INFO  [alembic.runtime.migration] Running upgrade 1b38cef5b76e -> 2e541a1dcfed, Change ``task_instance.task_duration`` type to ``FLOAT``
# INFO  [alembic.runtime.migration] Running upgrade 2e541a1dcfed -> 40e67319e3a9, Add ``conf`` column in ``dag_run`` table
# INFO  [alembic.runtime.migration] Running upgrade 40e67319e3a9 -> 561833c1c74b, Add ``password`` column to ``user`` table
# INFO  [alembic.runtime.migration] Running upgrade 561833c1c74b -> 4446e08588, Add ``start_date`` and ``end_date`` in ``dag_run`` table
# INFO  [alembic.runtime.migration] Running upgrade 4446e08588 -> bbc73705a13e, Add ``notification_sent`` column to ``sla_miss`` table
# INFO  [alembic.runtime.migration] Running upgrade bbc73705a13e -> bba5a7cfc896, Add a column to track the encryption state of the 'Extra' field in connection
# INFO  [alembic.runtime.migration] Running upgrade bba5a7cfc896 -> 1968acfc09e3, Add ``is_encrypted`` column to variable table
# INFO  [alembic.runtime.migration] Running upgrade 1968acfc09e3 -> 2e82aab8ef20, Rename user table
# INFO  [alembic.runtime.migration] Running upgrade 2e82aab8ef20 -> 211e584da130, Add TI state index
# INFO  [alembic.runtime.migration] Running upgrade 211e584da130 -> 64de9cddf6c9, Add ``task_fail`` table
# INFO  [alembic.runtime.migration] Running upgrade 64de9cddf6c9 -> f2ca10b85618, Add ``dag_stats`` table
# INFO  [alembic.runtime.migration] Running upgrade f2ca10b85618 -> 4addfa1236f1, Add fractional seconds to MySQL tables
# INFO  [alembic.runtime.migration] Running upgrade 4addfa1236f1 -> 8504051e801b, Add indices on ``xcom`` table
# INFO  [alembic.runtime.migration] Running upgrade 8504051e801b -> 5e7d17757c7a, Add ``pid`` field to ``TaskInstance``
# INFO  [alembic.runtime.migration] Running upgrade 5e7d17757c7a -> 127d2bf2dfa7, Add ``dag_id``/``state`` index on ``dag_run`` table
# INFO  [alembic.runtime.migration] Running upgrade 127d2bf2dfa7 -> cc1e65623dc7, Add ``max_tries`` column to ``task_instance``
# INFO  [alembic.runtime.migration] Running upgrade cc1e65623dc7 -> bdaa763e6c56, Make xcom value column a large binary
# INFO  [alembic.runtime.migration] Running upgrade bdaa763e6c56 -> 947454bf1dff, Create index on ``job_id`` column in ``task_instance`` table
# INFO  [alembic.runtime.migration] Running upgrade 947454bf1dff -> d2ae31099d61, Increase text size for MySQL (not relevant for other DBs' text types)
# INFO  [alembic.runtime.migration] Running upgrade d2ae31099d61 -> 0e2a74e0fc9f, Add time zone awareness
# INFO  [alembic.runtime.migration] Running upgrade d2ae31099d61 -> 33ae817a1ff4, Add Kubernetes resource check-pointing
# INFO  [alembic.runtime.migration] Running upgrade 33ae817a1ff4 -> 27c6a30d7c24, Add ``executor_config`` column to ``task_instance`` table
# INFO  [alembic.runtime.migration] Running upgrade 27c6a30d7c24 -> 86770d1215c0, Add kubernetes scheduler uniqueness
# INFO  [alembic.runtime.migration] Running upgrade 86770d1215c0, 0e2a74e0fc9f -> 05f30312d566, Merge migrations Heads
# INFO  [alembic.runtime.migration] Running upgrade 05f30312d566 -> f23433877c24, Fix MySQL not null constraint
# INFO  [alembic.runtime.migration] Running upgrade f23433877c24 -> 856955da8476, Fix Sqlite foreign key
# INFO  [alembic.runtime.migration] Running upgrade 856955da8476 -> 9635ae0956e7, Create index on ``task_fail`` table
# INFO  [alembic.runtime.migration] Running upgrade 9635ae0956e7 -> dd25f486b8ea, Add index on ``log`` table
# INFO  [alembic.runtime.migration] Running upgrade dd25f486b8ea -> bf00311e1990, Add index to ``task_instance`` table
# INFO  [alembic.runtime.migration] Running upgrade 9635ae0956e7 -> 0a2a5b66e19d, Add ``task_reschedule`` table
# INFO  [alembic.runtime.migration] Running upgrade 0a2a5b66e19d, bf00311e1990 -> 03bc53e68815, Merge migrations Heads
# INFO  [alembic.runtime.migration] Running upgrade 03bc53e68815 -> 41f5f12752f8, Add superuser field
# INFO  [alembic.runtime.migration] Running upgrade 41f5f12752f8 -> c8ffec048a3b, Add ``description`` and ``default_view`` column to ``dag`` table
# INFO  [alembic.runtime.migration] Running upgrade c8ffec048a3b -> dd4ecb8fbee3, Add schedule interval to dag
# INFO  [alembic.runtime.migration] Running upgrade dd4ecb8fbee3 -> 939bb1e647c8, task reschedule foreign key on cascade delete
# INFO  [alembic.runtime.migration] Running upgrade 939bb1e647c8 -> 6e96a59344a4, Make ``TaskInstance.pool`` not nullable
# INFO  [alembic.runtime.migration] Running upgrade 6e96a59344a4 -> d38e04c12aa2, Add ``serialized_dag`` table
# INFO  [alembic.runtime.migration] Running upgrade d38e04c12aa2 -> b3b105409875, Add ``root_dag_id`` to ``DAG``
# INFO  [alembic.runtime.migration] Running upgrade 6e96a59344a4 -> 74effc47d867, change datetime to datetime2(6) on MSSQL tables
# INFO  [alembic.runtime.migration] Running upgrade 939bb1e647c8 -> 004c1210f153, Increase queue name size limit
# INFO  [alembic.runtime.migration] Running upgrade c8ffec048a3b -> a56c9515abdc, Remove ``dag_stat`` table
# INFO  [alembic.runtime.migration] Running upgrade a56c9515abdc, 004c1210f153, 74effc47d867, b3b105409875 -> 08364691d074, Straighten out the migrations
# INFO  [alembic.runtime.migration] Running upgrade 08364691d074 -> fe461863935f, Increase length for connection password
# INFO  [alembic.runtime.migration] Running upgrade fe461863935f -> 7939bcff74ba, Add ``DagTags`` table
# INFO  [alembic.runtime.migration] Running upgrade 7939bcff74ba -> a4c2fd67d16b, Add ``pool_slots`` field to ``task_instance``
# INFO  [alembic.runtime.migration] Running upgrade a4c2fd67d16b -> 852ae6c715af, Add ``RenderedTaskInstanceFields`` table
# INFO  [alembic.runtime.migration] Running upgrade 852ae6c715af -> 952da73b5eff, Add ``dag_code`` table
# INFO  [alembic.runtime.migration] Running upgrade 952da73b5eff -> a66efa278eea, Add Precision to ``execution_date`` in ``RenderedTaskInstanceFields`` table
# INFO  [alembic.runtime.migration] Running upgrade a66efa278eea -> da3f683c3a5a, Add ``dag_hash`` Column to ``serialized_dag`` table
# INFO  [alembic.runtime.migration] Running upgrade da3f683c3a5a -> 92c57b58940d, Create FAB Tables
# INFO  [alembic.runtime.migration] Running upgrade 92c57b58940d -> 03afc6b6f902, Increase length of ``Flask-AppBuilder`` ``ab_view_menu.name`` column
# INFO  [alembic.runtime.migration] Running upgrade 03afc6b6f902 -> cf5dc11e79ad, Drop ``user`` and ``chart`` table
# INFO  [alembic.runtime.migration] Running upgrade cf5dc11e79ad -> bbf4a7ad0465, Remove id column from xcom
# INFO  [alembic.runtime.migration] Running upgrade bbf4a7ad0465 -> b25a55525161, Increase length of pool name
# INFO  [alembic.runtime.migration] Running upgrade b25a55525161 -> 3c20cacc0044, Add ``run_type`` column in ``dag_run`` table
# INFO  [alembic.runtime.migration] Running upgrade 3c20cacc0044 -> 8f966b9c467a, Set ``conn_type`` as non-nullable
# INFO  [alembic.runtime.migration] Running upgrade 8f966b9c467a -> 8d48763f6d53, Add unique constraint to ``conn_id``
# INFO  [alembic.runtime.migration] Running upgrade 8d48763f6d53 -> e38be357a868, Add ``sensor_instance`` table
# INFO  [alembic.runtime.migration] Running upgrade e38be357a868 -> b247b1e3d1ed, Add queued by Job ID to TI
# INFO  [alembic.runtime.migration] Running upgrade b247b1e3d1ed -> e1a11ece99cc, Add external executor ID to TI
# INFO  [alembic.runtime.migration] Running upgrade e1a11ece99cc -> bef4f3d11e8b, Drop ``KubeResourceVersion`` and ``KubeWorkerId``
# INFO  [alembic.runtime.migration] Running upgrade bef4f3d11e8b -> 98271e7606e2, Add ``scheduling_decision`` to ``DagRun`` and ``DAG``
# INFO  [alembic.runtime.migration] Running upgrade 98271e7606e2 -> 52d53670a240, fix_mssql_exec_date_rendered_task_instance_fields_for_MSSQL
# INFO  [alembic.runtime.migration] Running upgrade 52d53670a240 -> 364159666cbd, Add ``creating_job_id`` to ``DagRun`` table
# INFO  [alembic.runtime.migration] Running upgrade 364159666cbd -> 45ba3f1493b9, add-k8s-yaml-to-rendered-templates
# INFO  [alembic.runtime.migration] Running upgrade 45ba3f1493b9 -> 849da589634d, Prefix DAG permissions.
# INFO  [alembic.runtime.migration] Running upgrade 849da589634d -> 2c6edca13270, Resource based permissions.
# Traceback (most recent call last):
#   File "c:\users\gaoyu\appdata\local\programs\python\python39\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\gaoyu\appdata\local\programs\python\python39\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\gaoyu\AppData\Local\Programs\Python\Python39\Scripts\airflow.exe\__main__.py", line 7, in <module>
#   File "c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages\airflow\__main__.py", line 38, in main
#     args.func(args)
#   File "c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages\airflow\cli\cli_parser.py", line 51, in command
#     return func(*args, **kwargs)
#   File "c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages\airflow\cli\commands\standalone_command.py", line 48, in entrypoint
#     StandaloneCommand().run()
#   File "c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages\airflow\cli\commands\standalone_command.py", line 64, in run
#     self.initialize_database()
#   File "c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages\airflow\cli\commands\standalone_command.py", line 172, in initialize_database
#     db.initdb()
#   File "c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages\airflow\utils\session.py", line 71, in wrapper
#     return func(*args, session=session, **kwargs)
#   File "c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages\airflow\utils\db.py", line 649, in initdb
#     upgradedb(session=session)
#   File "c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages\airflow\utils\session.py", line 68, in wrapper
#     return func(*args, **kwargs)
#   File "c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages\airflow\utils\db.py", line 1463, in upgradedb
#     command.upgrade(config, revision=to_revision or 'heads')
#   File "c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages\alembic\command.py", line 322, in upgrade
#     script.run_env()
#   File "c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages\alembic\script\base.py", line 569, in run_env
#     util.load_python_file(self.dir, "env.py")
#   File "c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages\alembic\util\pyfiles.py", line 94, in load_python_file
#     module = load_module_py(module_id, path)
#   File "c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages\alembic\util\pyfiles.py", line 110, in load_module_py
#     spec.loader.exec_module(module)  # type: ignore
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages\airflow\migrations\env.py", line 107, in <module>
#     run_migrations_online()
#   File "c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages\airflow\migrations\env.py", line 101, in run_migrations_online
#     context.run_migrations()
#   File "<string>", line 8, in run_migrations
#   File "c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages\alembic\runtime\environment.py", line 853, in run_migrations
#     self.get_context().run_migrations(**kw)
#   File "c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages\alembic\runtime\migration.py", line 623, in run_migrations
#     step.migration_fn(**kw)
#   File "c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages\airflow\migrations\versions\0074_2_0_0_resource_based_permissions.py", line 342, in upgrade
#     remap_permissions()
#   File "c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages\airflow\migrations\versions\0074_2_0_0_resource_based_permissions.py", line 290, in remap_permissions
#     appbuilder = create_app(config={'FAB_UPDATE_PERMS': False}).appbuilder
#   File "c:\users\gaoyu\appdata\local\programs\python\python39\lib\site-packages\airflow\www\app.py", line 84, in create_app
#     raise AirflowConfigException(
# airflow.exceptions.AirflowConfigException: Cannot use relative path: `sqlite:///C:\Users\gaoyu/airflow/airflow.db` to connect to sqlite. Please use absolute path such as `sqlite:////tmp/airflow.db`.

# %% [markdown]
# ##### END
